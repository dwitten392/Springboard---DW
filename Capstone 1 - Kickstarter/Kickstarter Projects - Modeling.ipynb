# %% [markdown]
# # Kickstarter Projects

# %%
#change display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Can we predict which Kickstarter projects will be successful?

# %% [markdown]
# ## Data Cleaning and Exploration

# %%
#import pandas, matplotlib, seaborn, other packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import scipy.stats as scs
from mpl_toolkits.mplot3d import Axes3D

# %%
#change the float display for when using .describe()
pd.options.display.float_format = "{:.2f}".format

# %%
#read in and preview file
#download path https://www.kaggle.com/toshimelonhead/400000-kickstarter-projects
file_path = 'kickstarter.csv'

data = pd.read_csv(file_path, index_col = 'Unnamed: 0')
print(data.head(1))
data.info()
# Out:
#           id  backers_count  \
# 0  857125548              1
#
#                                                blurb currency    goal  \
# 0  Exploring paint and its place in a digital world.      USD 2000.00
#
#            launched_at             deadline location.country   name  \
# 0  2015-03-19 22:34:57  2015-04-30 23:12:00               US  Remix
#
#    usd_pledged  ... days_to_deadline  goal_USD  category_name  category_slug  \
# 0        25.00  ...               42   2000.00    Digital Art            art
#
#   blurb_length  location_type  location_country  location_state  \
# 0            9           Town                US              NY
#
#    location_displayable_name  binary_state
# 0               New York, NY        failed
#
# [1 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430938 entries, 0 to 768
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         430938 non-null  int64
#  1   backers_count              430938 non-null  int64
#  2   blurb                      430938 non-null  object
#  3   currency                   430938 non-null  object
#  4   goal                       430938 non-null  float64
#  5   launched_at                430938 non-null  object
#  6   deadline                   430938 non-null  object
#  7   location.country           429843 non-null  object
#  8   name                       430934 non-null  object
#  9   usd_pledged                430938 non-null  float64
#  10  slug                       430938 non-null  object
#  11  spotlight                  430938 non-null  bool
#  12  staff_pick                 430938 non-null  bool
#  13  static_usd_rate            430938 non-null  float64
#  14  state                      430938 non-null  object
#  15  year                       430938 non-null  int64
#  16  month                      430938 non-null  int64
#  17  day                        430938 non-null  int64
#  18  hour                       430938 non-null  int64
#  19  days_to_deadline           430938 non-null  int64
#  20  goal_USD                   430938 non-null  float64
#  21  category_name              430938 non-null  object
#  22  category_slug              430938 non-null  object
#  23  blurb_length               430938 non-null  int64
#  24  location_type              430938 non-null  object
#  25  location_country           430938 non-null  object
#  26  location_state             430938 non-null  object
#  27  location_displayable_name  430938 non-null  object
#  28  binary_state               430938 non-null  object
# dtypes: bool(2), float64(4), int64(8), object(15)
# memory usage: 92.9+ MB

# %%
#attempt to understand goal_USD data shape by only looking at data under 20k
data['goal_USD'].loc[data['goal_USD'] < 20000].hist(bins = 20, figsize=(18,8))
plt.title('Histogram of Projects with Goals under $20K')
plt.show()

# %%
#Checking first 1000 category against 2nd 1000. Already by the second, failure is more likely than success.
fig=plt.figure(figsize=(15,5.5))
plt.subplot(1,2,1)
plt.title('Under $1000 Success Count')
data['binary_state'].loc[data['goal_USD'] < 1000].value_counts().plot(kind='bar')
plt.subplot(1,2,2)
plt.title("Range: $1000 - $2000 Success Count")
data['binary_state'].loc[(data['goal_USD'] >= 1000) & (data['goal_USD'] < 2000)].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# I decided to throw out data with a goal under $1000 as they do not seem to be "serious" crowdfunding projects.

# %%
#throwing data with a goal under 1000
cleaned_data = data.loc[data['goal_USD'] >= 1000]
#removing data from memory
del data

# %%
#print out approximate time when data was captured
print(cleaned_data['launched_at'].max())
#filter out data where target date is beyond the date of the data
cleaned_data = cleaned_data.loc[cleaned_data['deadline'] <= cleaned_data['launched_at'].max()]
# Out:
# 2019-04-18 04:49:38

# %% [markdown]
# I threw out data where the deadline is beyond the cutoff date

# %% [markdown]
# ## Is ID an appropriate Index?

# %%
#is ID an appropriate index?
cleaned_data.id.nunique()
# Out:
# 267679

# %% [markdown]
# ID is not an appropriate index as there are many duplicates

# %%
#look at some duplicated ID values
cleaned_data[cleaned_data.id.duplicated(keep=False)].sort_values('id').head(7)
# Out:
#          id  backers_count                                              blurb  \
# 3619   8624            737  A compact outdoor cooking set that you can use...
# 865    8624            499  A compact outdoor cooking set that you can use...
# 1446   8624            498  A compact outdoor cooking set that you can use...
# 2753  18520              2  Raising money to help my grandmother recover f...
# 3348  18520              4  Raising money to help my grandmother recover f...
# 3511  38736              3  All your herbal tea remedies here. From colds ...
# 3006  38736              3  All your herbal tea remedies here. From colds ...
#
#      currency     goal          launched_at             deadline  \
# 3619      EUR 30000.00  2018-02-22 09:44:29  2018-03-29 08:44:29
# 865       EUR 30000.00  2018-02-22 09:44:29  2018-03-29 08:44:29
# 1446      EUR 30000.00  2018-02-22 09:44:29  2018-03-29 08:44:29
# 2753      USD 15000.00  2016-10-19 13:32:40  2016-11-18 14:32:40
# 3348      USD 15000.00  2016-10-19 13:32:40  2016-11-18 14:32:40
# 3511      USD  2500.00  2018-08-22 03:51:56  2018-10-21 03:51:56
# 3006      USD  2500.00  2018-08-22 03:51:56  2018-10-21 03:51:56
#
#      location.country                                               name  \
# 3619               US  Kombuis a portable and efficient rocket stove ...
# 865                US  Kombuis a portable and efficient rocket stove ...
# 1446               US  Kombuis a portable and efficient rocket stove ...
# 2753               US                                 Grandma's are Life
# 3348               US                                 Grandma's are Life
# 3511               US                                        Herbal Teas
# 3006               US                                        Herbal Teas
#
#       usd_pledged  ... days_to_deadline  goal_USD   category_name  \
# 3619     93005.59  ...               35  36966.30  Product Design
# 865      59989.76  ...               35  36966.30  Product Design
# 1446     59871.47  ...               35  36966.30  Product Design
# 2753        11.00  ...               30  15000.00     World Music
# 3348        62.00  ...               30  15000.00     World Music
# 3511        96.00  ...               60   2500.00          Drinks
# 3006        96.00  ...               60   2500.00          Drinks
#
#       category_slug blurb_length  location_type  location_country  \
# 3619         design           12           Town                US
# 865          design           12           Town                US
# 1446         design           12           Town                US
# 2753          music           24           Town                US
# 3348          music           24           Town                US
# 3511           food           21           Town                US
# 3006           food           21           Town                US
#
#       location_state  location_displayable_name  binary_state
# 3619              WV                Belgium, WV    successful
# 865               WV                Belgium, WV    successful
# 1446              WV                Belgium, WV    successful
# 2753              OH              Cleveland, OH        failed
# 3348              OH              Cleveland, OH        failed
# 3511              NY                Livonia, NY        failed
# 3006              NY                Livonia, NY        failed
#
# [7 rows x 29 columns]

# %% [markdown]
# The same projects are captured at different points in time, I will remove duplicate ID lines taking information from the most recent information (highest USD pledged)

# %%
#dropping duplicates, note sorting by usd pledged so I only keep the most recent data (unlikely pledged amount goes down)
cleaned_data = cleaned_data.sort_values('usd_pledged', ascending = False).drop_duplicates(subset = 'id', keep = 'first')
cleaned_data.id.describe()
# Out:
# count       267679.00
# mean    1073459652.11
# std      619440051.22
# min           8624.00
# 25%      536011791.50
# 50%     1075032467.00
# 75%     1608601833.00
# max     2147476221.00
# Name: id, dtype: float64

# %% [markdown]
# ID is now a unique column, so it can be set as the index

# %%
#drop old index and replace with ID column
cleaned_data = cleaned_data.reset_index(drop=True).set_index('id').sort_index()

# %% [markdown]
# ## Date Time Columns

# %%
#create a new column for days between launch and goal date
cleaned_data['launched_at'] = pd.to_datetime(cleaned_data['launched_at'])
cleaned_data['deadline'] = pd.to_datetime(cleaned_data['deadline'])
cleaned_data['days_between'] = (cleaned_data['deadline'] - cleaned_data['launched_at']).dt.days

# %% [markdown]
# ## Creating Additional Columns

# %%
#create a proportion of goal column
cleaned_data['prop_goal'] = cleaned_data['usd_pledged'] / cleaned_data['goal_USD']
cleaned_data.prop_goal.head()
# Out:
# id
# 8624    2.52
# 18520   0.00
# 24380   0.04
# 33867   0.16
# 38736   0.04
# Name: prop_goal, dtype: float64

# %%
#strip out city name
cleaned_data['city'] = [i.split(', ')[0] for i in cleaned_data['location_displayable_name']]
cleaned_data.city.head()
# Out:
# id
# 8624         Belgium
# 18520      Cleveland
# 24380    Bloomington
# 33867      Vancouver
# 38736        Livonia
# Name: city, dtype: object

# %%
#count the length of the name
cleaned_data['name_length'] = [len(str(i).split()) for i in cleaned_data.name]
cleaned_data.name_length.head()
# Out:
# id
# 8624     10
# 18520     3
# 24380     9
# 33867     5
# 38736     2
# Name: name_length, dtype: int64

# %%
#convert success to boolean
d = {'successful' : 1, 'failed' : 0}
cleaned_data.binary_state = cleaned_data.binary_state.map(d)

# %% [markdown]
# ## Looking at Text Columns (blurb and name)

# %%
#looking for help as the first word in the blurb
cleaned_data['help_first_blurb'] = [('help' == str(i)[0:4].lower()) for i in cleaned_data.blurb]
print(cleaned_data.help_first_blurb.value_counts())
print((cleaned_data['help_first_blurb'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['help_first_blurb'].value_counts()))
# Out:
# False    260978
# True       6701
# Name: help_first_blurb, dtype: int64
# False   0.43
# True    0.56
# Name: help_first_blurb, dtype: float64

# %% [markdown]
# Highlighting the purpose of helping someone is helpful for success.

# %%
#looking for luxury in blurb
cleaned_data['luxury_blurb'] = ['luxury' in str(i).lower() for i in cleaned_data.blurb]
print(cleaned_data.luxury_blurb.value_counts())
print((cleaned_data['luxury_blurb'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['luxury_blurb'].value_counts()))
#luxury doesn't appear that often, so dropping it
cleaned_data.drop(['luxury_blurb'], axis = 1, inplace = True)
# Out:
# False    266872
# True        807
# Name: luxury_blurb, dtype: int64
# False   0.43
# True    0.40
# Name: luxury_blurb, dtype: float64

# %% [markdown]
# Luxury did not appear often in blurb. I decided to remove it.

# %%
#looking for family in blurb
cleaned_data['family_blurb'] = ['family' in str(i).lower() for i in cleaned_data.blurb]
print(cleaned_data.family_blurb.value_counts())
print((cleaned_data['family_blurb'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['family_blurb'].value_counts()))

#removing
cleaned_data.drop(['family_blurb'], axis = 1, inplace = True)
# Out:
# False    263225
# True       4454
# Name: family_blurb, dtype: int64
# False   0.43
# True    0.40
# Name: family_blurb, dtype: float64

# %% [markdown]
# The word family in blurb was correlated with slightly less success and did not appear often. I decided to remove the variable

# %%
#check if the first word of the blurb or name is lowercase
def lowercase_first(row):
    y = ((str(row['blurb'])[0:2].islower()) and (str(row['blurb'])[0:2].isalpha()) or ((str(row['name'])[0:2].islower()) and (str(row['name'])[0:2].isalpha())))
    return y

cleaned_data['lowercase_first'] = cleaned_data.apply(lowercase_first, axis=1)

print(cleaned_data.lowercase_first.value_counts())
print((cleaned_data['lowercase_first'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['lowercase_first'].value_counts()))
# Out:
# False    261795
# True       5884
# Name: lowercase_first, dtype: int64
# False   0.44
# True    0.30
# Name: lowercase_first, dtype: float64

# %% [markdown]
# Lack of capitalization might indicate informality or lack of attention to detail.

# %%
#check if the the first word of the name is all capitalized
cleaned_data['first_name_cap'] = [(str(i)[0:2].isupper()) and (str(i)[0:2].isalpha()) for i in cleaned_data.name]
print(cleaned_data.first_name_cap.value_counts())
print((cleaned_data['first_name_cap'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['first_name_cap'].value_counts()))

#check if the the first word of the blurb is capitalized wasn't as impactful
# Out:
# False    236085
# True      31594
# Name: first_name_cap, dtype: int64
# False   0.43
# True    0.49
# Name: first_name_cap, dtype: float64

# %% [markdown]
# Those projects capitalizing the first word of the name had a slightly higher probability of success.

# %%
#does the blurb contain an exclamation point? Does the name?

def exclam_first(row):
    y = ("!" in str(row['blurb']) or "!" in str(row['name']))
    return y

cleaned_data['exclam'] = cleaned_data.apply(exclam_first, axis=1)

print(cleaned_data.exclam.value_counts())
print((cleaned_data['exclam'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['exclam'].value_counts()))
# Out:
# False    195799
# True      71880
# Name: exclam, dtype: int64
# False   0.42
# True    0.48
# Name: exclam, dtype: float64

# %%
#does the blurb contain best or better?
cleaned_data['blurb_best'] = ['best' in str(i).lower() or 'better' in str(i).lower() for i in cleaned_data.blurb]
print(cleaned_data.blurb_best.value_counts())
print((cleaned_data['blurb_best'].loc[cleaned_data['binary_state'] == 1].value_counts())/(cleaned_data['blurb_best'].value_counts()))

#didn't appear to be impactful so i dropped
cleaned_data.drop(['blurb_best'], axis = 1, inplace = True)
# Out:
# False    260746
# True       6933
# Name: blurb_best, dtype: int64
# False   0.43
# True    0.42
# Name: blurb_best, dtype: float64

# %% [markdown]
# ## Additional Cleaning (Dropping Columns)

# %%
#confirm staff_pick and spotlight highly correlated with success, but are not useful for prediction purposes.
print("The proportion of projects that are a staff pick: " + str(round(cleaned_data.staff_pick.mean(), 3)) + ".")
print("The proportion of projects that are a staff pick successful are: " + str(round(cleaned_data.binary_state.loc[cleaned_data.staff_pick == True].mean(), 3)) + ".")
print("")
print("The proportion of projects that are spotlighted: " + str(round(cleaned_data.spotlight.mean(), 3)) + ".")
print("The proportion of projects that are spotlighted and successful: " + str(round(cleaned_data.binary_state.loc[cleaned_data.spotlight == True].mean(), 3)) + ".")
# Out:
# The proportion of projects that are a staff pick: 0.12.
# The proportion of projects that are a staff pick successful are: 0.837.
#
# The proportion of projects that are spotlighted: 0.429.
# The proportion of projects that are spotlighted and successful: 1.0.

# %%
# dropping the location.country column (already location_country column); 
# the days to deadline not useful as the deadline should be passed;
# the state column is not necessary with the binary_state column; and the individual date columns are not necessary
# the spotlight and staff pick columns can be dropped
# dropping a few additional columns I don't plan to use

cleaned_data = cleaned_data.drop(columns=['location.country', 'days_to_deadline', 'state', 
                                 'year', 'month', 'day', 'hour', 'spotlight', 'staff_pick', 'location_displayable_name', 'slug'])

# %% [markdown]
# Dropping unnecessary columns

# %%
#looking at info of cleaning data
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267679 entries, 8624 to 2147476221
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   backers_count     267679 non-null  int64
#  1   blurb             267679 non-null  object
#  2   currency          267679 non-null  object
#  3   goal              267679 non-null  float64
#  4   launched_at       267679 non-null  datetime64[ns]
#  5   deadline          267679 non-null  datetime64[ns]
#  6   name              267676 non-null  object
#  7   usd_pledged       267679 non-null  float64
#  8   static_usd_rate   267679 non-null  float64
#  9   goal_USD          267679 non-null  float64
#  10  category_name     267679 non-null  object
#  11  category_slug     267679 non-null  object
#  12  blurb_length      267679 non-null  int64
#  13  location_type     267679 non-null  object
#  14  location_country  267679 non-null  object
#  15  location_state    267679 non-null  object
#  16  binary_state      267679 non-null  int64
#  17  days_between      267679 non-null  int64
#  18  prop_goal         267679 non-null  float64
#  19  city              267679 non-null  object
#  20  name_length       267679 non-null  int64
#  21  help_first_blurb  267679 non-null  bool
#  22  lowercase_first   267679 non-null  bool
#  23  first_name_cap    267679 non-null  bool
#  24  exclam            267679 non-null  bool
# dtypes: bool(4), datetime64[ns](2), float64(5), int64(5), object(9)
# memory usage: 46.0+ MB

# %%
#examining data lines for more insights on keywords
cleaned_data.head(8)
# Out:
#        backers_count                                              blurb  \
# id
# 8624             737  A compact outdoor cooking set that you can use...
# 18520              4  Raising money to help my grandmother recover f...
# 24380             18  A sanctuary for humans and felines alike! Come...
# 33867             42  Taste Makers is a socially conscious brand tha...
# 38736              3  All your herbal tea remedies here. From colds ...
# 39036             68  The BEST beef sticks, beef jerky and signature...
# 39235            338  4tec is a classic 4 in a row table top game, r...
# 39409             66  CalArts thesis film inspired by true events su...
#
#       currency     goal         launched_at            deadline  \
# id
# 8624       EUR 30000.00 2018-02-22 09:44:29 2018-03-29 08:44:29
# 18520      USD 15000.00 2016-10-19 13:32:40 2016-11-18 14:32:40
# 24380      USD 20000.00 2015-10-27 15:25:33 2015-11-26 16:25:33
# 33867      CAD 18000.00 2015-06-15 18:28:11 2015-07-30 18:28:11
# 38736      USD  2500.00 2018-08-22 03:51:56 2018-10-21 03:51:56
# 39036      USD  2500.00 2016-05-16 22:34:18 2016-06-30 22:34:18
# 39235      EUR  5000.00 2018-09-10 06:48:50 2018-10-10 06:48:50
# 39409      USD 10500.00 2011-07-20 19:28:17 2011-08-19 19:28:17
#
#                                                     name  usd_pledged  \
# id
# 8624   Kombuis a portable and efficient rocket stove ...     93005.59
# 18520                                 Grandma's are Life        62.00
# 24380  Puss N' Books: A relaxing cat cafe and bookstore.       776.00
# 33867                            TASTE MAKERS BY TRISH P      2271.72
# 38736                                        Herbal Teas        96.00
# 39036                          The Meat Candy Experience      3239.00
# 39235                      4tec: a New 3D Connect 4 Game     15440.03
# 39409                              WHILE THE TREES SLEEP     11545.00
#
#        static_usd_rate  goal_USD  ... location_state binary_state  \
# id                                ...
# 8624              1.23  36966.30  ...             WV            1
# 18520             1.00  15000.00  ...             OH            0
# 24380             1.00  20000.00  ...             IL            0
# 33867             0.81  14614.38  ...             BC            0
# 38736             1.00   2500.00  ...             NY            0
# 39036             1.00   2500.00  ...             WI            1
# 39235             1.16   5781.92  ...         Dublin            1
# 39409             1.00  10500.00  ...             MO            1
#
#        days_between prop_goal          city name_length  help_first_blurb  \
# id
# 8624             34      2.52       Belgium          10             False
# 18520            30      0.00     Cleveland           3             False
# 24380            30      0.04   Bloomington           9             False
# 33867            45      0.16     Vancouver           5             False
# 38736            60      0.04       Livonia           2             False
# 39036            45      1.30  Kronenwetter           4             False
# 39235            30      2.67        Dublin           7             False
# 39409            30      1.10      Columbia           4             False
#
#        lowercase_first  first_name_cap exclam
# id
# 8624             False           False  False
# 18520            False           False  False
# 24380            False           False   True
# 33867            False            True  False
# 38736            False           False  False
# 39036            False           False  False
# 39235            False           False  False
# 39409            False            True  False
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Data Visualization

# %%
#histogram of days between
fig=plt.figure(figsize=(15,5.5))
x = cleaned_data['days_between'].loc[cleaned_data['binary_state'] == True]
y = cleaned_data['days_between'].loc[cleaned_data['binary_state'] == False]
bins = np.linspace(0, 92, 92)

plt.hist(x, bins, alpha=0.8, label='Success')
plt.hist(y, bins, alpha=0.5, label='Failed')
plt.legend(loc='upper right')
plt.title('Histogram of Difference between Deadline and Lauch Date')
plt.show()

print('\033[1m' + "Success Descriptive Statistics" + '\033[0m')
print(x.describe())
print('')
print('\033[1m' + "Failed Descriptive Statistics" + '\033[0m')
print(y.describe())
# Out:
# Success Descriptive Statistics
# count   116077.00
# mean        32.57
# std         11.20
# min          1.00
# 25%         29.00
# 50%         30.00
# 75%         34.00
# max         91.00
# Name: days_between, dtype: float64
#
# Failed Descriptive Statistics
# count   151602.00
# mean        35.48
# std         12.63
# min          1.00
# 25%         30.00
# 50%         30.00
# 75%         40.00
# max         92.00
# Name: days_between, dtype: float64

# %% [markdown]
# Most Kickstarters have the deadline set at around 30 days from the launch date.

# %%
fig=plt.figure(figsize=(15,5.5))
x = cleaned_data['blurb_length'].loc[cleaned_data['binary_state'] == True]
y = cleaned_data['blurb_length'].loc[cleaned_data['binary_state'] == False]
bins = np.linspace(0, 36, 36)

plt.hist(x, bins=bins, alpha=0.8, label='Success')
plt.hist(y, bins=bins, alpha=0.5, label='Failed')
plt.legend(loc='upper right')
plt.title('Histogram of Blurb Length')
plt.show()
print('\033[1m' + "Success Descriptive Statistics" + '\033[0m')
print(x.describe())
print('')
print('\033[1m' + "Failed Descriptive Statistics" + '\033[0m')
print(y.describe())
# Out:
# Success Descriptive Statistics
# count   116077.00
# mean        19.11
# std          4.65
# min          1.00
# 25%         17.00
# 50%         20.00
# 75%         22.00
# max         35.00
# Name: blurb_length, dtype: float64
#
# Failed Descriptive Statistics
# count   151602.00
# mean        19.19
# std          5.13
# min          1.00
# 25%         17.00
# 50%         20.00
# 75%         23.00
# max         36.00
# Name: blurb_length, dtype: float64

# %% [markdown]
# Both successful and unsuccessful projects have a similar blurb length distribution

# %%
#bootstrap statistics on the mean of blurb length, CAREFUL OF CALC TIME
#see x and y from above
N_rep = 5000
success_blurb_length_mean = np.empty(N_rep)
failed_blurb_length_mean = np.empty(N_rep)

for i in range(N_rep):
    success_blurb_length_mean[i] = np.mean(np.random.choice(x, size=len(x)))
    failed_blurb_length_mean[i] = np.mean(np.random.choice(y, size=len(y)))
    
mean_diff_blurb = failed_blurb_length_mean - success_blurb_length_mean

# %%
p_value = np.sum(mean_diff_blurb < 0) / N_rep
print(p_value)
# Out:
# 0.0

# %% [markdown]
# We can conclude that it is very likely that the failed blurb length has a larger mean than the successful blurb length despite the small difference.

# %%
fig=plt.figure(figsize=(15,5.5))
x = cleaned_data['name_length'].loc[cleaned_data['binary_state'] == True]
y = cleaned_data['name_length'].loc[cleaned_data['binary_state'] == False]
bins = np.linspace(0, 29, 29)
plt.hist(x, bins=bins, alpha=0.8, label='Success')
plt.hist(y, bins=bins, alpha=0.5, label='Failed')
plt.legend(loc='upper right')
plt.title('Histogram of Name Length')
plt.show()
print('\033[1m' + "Success Descriptive Statistics" + '\033[0m')
print(x.describe())
print('')
print('\033[1m' + "Failed Descriptive Statistics" + '\033[0m')
print(y.describe())
# Out:
# Success Descriptive Statistics
# count   116077.00
# mean         6.16
# std          2.72
# min          1.00
# 25%          4.00
# 50%          6.00
# 75%          8.00
# max         27.00
# Name: name_length, dtype: float64
#
# Failed Descriptive Statistics
# count   151602.00
# mean         5.53
# std          2.78
# min          1.00
# 25%          3.00
# 50%          5.00
# 75%          8.00
# max         29.00
# Name: name_length, dtype: float64

# %% [markdown]
# Longer blurbs were more likely to be successful on average. There is a high concentration of failures in the 1-4 name length range compared with the more uniform distribution of successes.

# %%
#bootstrap statistics on the mean of name length, CAREFUL OF CALC TIME
#see x and y from above
N_rep = 5000
success_name_length_mean = np.empty(N_rep)
failed_name_length_mean = np.empty(N_rep)

for i in range(N_rep):
    success_name_length_mean[i] = np.mean(np.random.choice(x, size=len(x)))
    failed_name_length_mean[i] = np.mean(np.random.choice(y, size=len(y)))
    
mean_diff_name = success_name_length_mean - failed_name_length_mean

# %%
p_value = np.sum(mean_diff_name < 0) / N_rep
print(p_value)
# Out:
# 0.0

# %% [markdown]
# We can conclude that it is very likely that the successful name length has a larger mean than the failed name length.

# %%
#plotting name length against blurb length
f, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(x='name_length', y='blurb_length', data=cleaned_data, palette = 'muted')
ax.set(ylabel="Blurb Length", xlabel = "Name Length", title = 'Blurb Length vs. Name Length')
plt.show()

# %%
# calculate Pearson's correlation
corr, _ = scs.pearsonr(cleaned_data.name_length, cleaned_data.blurb_length)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.148

# %% [markdown]
# The two variables are hardly correlated.

# %%
d = {1 : 'successful', 0 : 'failed'}
cleaned_data.binary_state = cleaned_data.binary_state.map(d)
#looking distribution of the backers_count column
f, ax = plt.subplots(figsize=(20, 6))
ax.set_xscale("log")
sns.boxplot(x="backers_count", y = 'binary_state', data=cleaned_data, palette = 'muted')
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel = "Number of Backers (Log Scale)", title = 'Number of Backers Distribution')
plt.show()

# %%
#looking at distribution of USD Pledged
f, ax = plt.subplots(figsize=(20, 6))
ax.set_xscale("log")
sns.boxplot(x="usd_pledged", y= 'binary_state', data=cleaned_data, palette = 'muted')
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel = "USD Pledged (Log Scale)", title = 'USD Pledged Distribution')
plt.show()

# %%
#looking at distribution of USD Goal
f, ax = plt.subplots(figsize=(20, 6))
ax.set_xscale("log")
sns.boxplot(x="goal_USD", y="binary_state", data=cleaned_data, palette = 'muted')
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel = "Goal USD (Log Scale)", title = 'Goal USD Distribution')
plt.show()

# %%
#look at proportion of goal column
print(cleaned_data.prop_goal.describe())

#looking distribution of the prop_goal column
f, ax = plt.subplots(figsize=(10, 3))
ax.set_xscale("log")
sns.boxplot(x="prop_goal", data=cleaned_data, palette = 'muted')
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel = "Proportion of Goal (Log Scale)", title = 'Proportion of Goal Distribution')
plt.show()
# Out:
# count   267679.00
# mean         1.03
# std          4.86
# min          0.00
# 25%          0.01
# 50%          0.24
# 75%          1.11
# max        926.57
# Name: prop_goal, dtype: float64

# %%
#histogram of Goal Distribution
fig=plt.figure(figsize=(15,5.5))
x = cleaned_data['prop_goal'].loc[cleaned_data['prop_goal'] < 2]
plt.hist(x, bins=8)
plt.xlabel('Proportion of Goal')
plt.ylabel('Count')
plt.title('Proportion of Goal (< 2) Histogram')
plt.show()

# %% [markdown]
# Projects usually do not get off the ground, but when they do, they tend to snowball just past the goal and then level off.

# %%
#day of the week bar chart

cleaned_data['day_week'] = cleaned_data['launched_at'].dt.day_name()
fig=plt.figure(figsize=(10,5.5))
chart = sns.countplot(x = 'day_week', hue= 'binary_state', data = cleaned_data, order = cleaned_data['day_week'].value_counts().index)
plt.xlabel('Day of Week')
plt.legend(title = '')
plt.title('Count of Day of the Week')
plt.show()
#probability distribution
y = (cleaned_data['day_week'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['day_week'].value_counts())
y = y.sort_values(ascending=False)
fig=plt.figure(figsize=(10,5.5))
ax = sns.barplot(x = y.index, y = y, palette = 'muted')
plt.xlabel('Day of Week')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Day of Week')
plt.show()

# %% [markdown]
# The middle of the week is the most popular launch time and has the highest probability of success.

# %% [markdown]
# ### Chi-squared Test for Categorical Data

# %%
# defining a function
from scipy.stats import chi2_contingency

def chisq_of_df_cols(df, c1, c2):
    groupsizes = df.groupby([c1, c2]).size()
    ctsum = groupsizes.unstack(c1)
    # fillna(0) is necessary to remove any NAs which will cause exceptions
    return(chi2_contingency(ctsum.fillna(0)))

# %%
#chi squared test for day of week and binary state
chisq_of_df_cols(cleaned_data, 'day_week', 'binary_state')
# Out:
# (481.8272899720435,
#  6.899720891982332e-101,
#  6,
#  array([[22474.76330231, 26445.49549274, 11549.72779336,  8898.60849749,
#          23723.58151368, 31729.04428812, 26780.77911229],
#         [17208.23669769, 20248.50450726,  8843.27220664,  6813.39150251,
#          18164.41848632, 24293.95571188, 20505.22088771]]))

# %% [markdown]
# We have sufficient evidence to conclude that the day of the week is not independent of binary state.

# %%
# COMMENTING OUT FOR NOW
#binning data into weekend
#cleaned_data['weekend'] = [(i =='Friday' or i =='Saturday' or i =='Sunday') for i in cleaned_data.day_week]
#cleaned_data['weekend'].value_counts()
#dropping day_week; only had 1% impact on accuracy for LogReg
#cleaned_data.drop(columns = 'day_week', inplace=True)

# %%
#month of launch count plot
cleaned_data['month'] = cleaned_data['launched_at'].dt.month_name()
fig=plt.figure(figsize=(15,5.5))
chart = sns.countplot(x = 'month', hue = 'binary_state', data = cleaned_data, order = cleaned_data['month'].value_counts().index)
plt.xlabel('Month')
plt.legend(title = '')
plt.title('Count of Month')
plt.show()
y = (cleaned_data['month'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['month'].value_counts())
y = y.sort_values(ascending=False)
fig=plt.figure(figsize=(15,5.5))
ax = sns.barplot(x = y.index, y = y, palette = 'muted')
plt.xlabel('Month')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Month')
plt.show()

# %% [markdown]
# There was not huge variability between months; however, December has been down months all around.

# %%
#chi squared test for day of week and binary state
chisq_of_df_cols(cleaned_data, 'month', 'binary_state')
# Out:
# (576.9576226212162,
#  1.184960560184379e-116,
#  11,
#  array([[12771.36084639, 12644.49677412,  8883.31684592, 12829.12930787,
#          12155.73028142, 13586.3492392 , 13094.75095917, 13786.27342451,
#          13307.70136619, 12699.43344827, 13427.76914887, 12415.68835807],
#         [ 9778.63915361,  9681.50322588,  6801.68315408,  9822.87069213,
#           9307.26971858, 10402.6507608 , 10026.24904083, 10555.72657549,
#          10189.29863381,  9723.56655173, 10281.23085113,  9506.31164193]]))

# %% [markdown]
# We have sufficient evidence to conclude that the month is not independent of binary state.

# %%
#year of launch count plot
cleaned_data['year'] = cleaned_data['launched_at'].dt.year
fig=plt.figure(figsize=(12,5.5))
chart = sns.countplot(x = 'year', hue = 'binary_state', data = cleaned_data, order = cleaned_data['year'].value_counts().index)
plt.xlabel('Year')
plt.legend(title = '')
plt.title('Count of Year')
plt.show()
y = (cleaned_data['year'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['year'].value_counts())
fig=plt.figure(figsize=(12,5.5))
ax = sns.barplot(x = y.index, y = y, order = y.index, palette = 'muted')
plt.xlabel('Year')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Year')
plt.show()

# %% [markdown]
# Note that 2019 data is not for a full year. Has the success rate changed in a predicatible pattern?
#
# It appear that the early years were most successful with a large drop in 2014 and then it eventually began to rebound.
#
# **What happened in 2014?**

# %%
#2014 Launches
fig=plt.figure(figsize=(15,5.5))
chart = sns.countplot(x = 'month', hue = 'binary_state', data = cleaned_data.loc[cleaned_data['year'] == 2014], order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
                                                                                                                        'September', 'October', 'November', 'December'])
plt.xlabel('Month')
plt.legend(title = '')
plt.title('Count of Month')
plt.show()

# %% [markdown]
# Activity explodes in June 2014.

# %%
#work in progress to figure out what happened in 2014
print('\033[1m' + '2013' + '\033[0m')
print(cleaned_data[['backers_count', 'usd_pledged', 'goal_USD', 'prop_goal']].loc[cleaned_data['year'] == 2013].describe())
print('')
print('\033[1m' + '2014' + '\033[0m')
print(cleaned_data[['backers_count', 'usd_pledged', 'goal_USD', 'prop_goal']].loc[cleaned_data['year'] == 2014].describe())
# Out:
# 2013
#        backers_count  usd_pledged    goal_USD  prop_goal
# count       23493.00     23493.00    23493.00   23493.00
# mean          225.91     17235.88    25687.66       1.20
# std          1304.08     93558.53   323337.36       2.98
# min             0.00         0.00     1000.00       0.00
# 25%            11.00       535.00     3000.00       0.07
# 50%            50.00      3365.00     6000.00       1.03
# 75%           136.00     10360.00    15000.00       1.21
# max         91585.00   5702153.38 31424010.40     106.08
#
# 2014
#        backers_count  usd_pledged     goal_USD  prop_goal
# count       38173.00     38173.00     38173.00   38173.00
# mean          135.38     11524.35     50608.01       0.83
# std           876.57     99827.00   1067704.99       3.44
# min             0.00         0.00      1000.00       0.00
# 25%             2.00        34.07      3000.00       0.00
# 50%            17.00      1112.54      7500.00       0.14
# 75%            80.00      6276.00     20000.00       1.08
# max        105857.00  13285226.36 100000000.00     365.54

# %%
print('The total number of backers in 2013 was ' + str(cleaned_data.backers_count.loc[cleaned_data['year'] == 2013].sum()) + '.')
print('')
print('The total number of backers in 2014 was ' + str(cleaned_data.backers_count.loc[cleaned_data['year'] == 2014].sum()) + '.')
# Out:
# The total number of backers in 2013 was 5307192.
#
# The total number of backers in 2014 was 5167952.

# %% [markdown]
# **Activity for project creation spiked in 2014, but the number of backers actually decreased. The mean target goal in USD nearly doubled. Success in 2013 was clearly more likely from just this information, but why did this activity spike and why were projects more ambitious in 2014?**

# %%
#show the frequency of location country for those with at least 3000 occurrences
fig = plt.figure(figsize = (12, 6))
sns.countplot(x = 'location_country', hue = 'binary_state', 
              data = cleaned_data[cleaned_data.location_country.isin(['US', 'GB', 'CA', 'AU', 'DE', 'FR', 'IT'])], 
              order = cleaned_data.location_country.loc[cleaned_data.location_country.isin(['US', 'GB', 'CA', 'AU', 'DE', 'FR', 'IT'])].value_counts().index)
plt.legend(title ='')
plt.xlabel('Location Country')
plt.title('Count of Location Country (> 3000)')
plt.show()
# make this into a probability distribution like above
y = (cleaned_data['location_country'].loc[cleaned_data['location_country'].isin(['US', 'GB', 'CA', 'AU', 'DE', 'FR', 'IT'])].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['location_country'].loc[cleaned_data['location_country'].isin(['US', 'GB', 'CA', 'AU', 'DE', 'FR', 'IT'])].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order = y.index, palette = 'muted')
plt.xlabel('Year')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Country')
plt.show()
print(y)
# Out:
# US   0.45
# GB   0.42
# FR   0.39
# CA   0.36
# DE   0.31
# AU   0.31
# IT   0.23
# Name: location_country, dtype: float64

# %% [markdown]
# There are only seven countries with more than 3000 occurrences. The US dominates with Great Britain and Canada coming in second and third. Due to fact US success is concentrated in certain states (see below) and other countries tend to not have many successes. I will drop location country.

# %%
#dropping location country
cleaned_data.drop(columns = 'location_country', inplace=True)

# %%
#show the frequency of currency
fig = plt.figure(figsize = (12, 6))
sns.countplot(x = 'currency', hue = 'binary_state', 
              data = cleaned_data,
              order = cleaned_data.currency.value_counts().index)
plt.legend(title ='')
plt.xlabel('Currency')
plt.title('Count of Currency')
plt.show()
# make this into a probability distribution like above
y = (cleaned_data['currency'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['currency'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order = y.index, palette = 'muted')
plt.xlabel('Year')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Currency')
plt.show()
print(y)
# Out:
# HKD   0.51
# USD   0.46
# JPY   0.43
# GBP   0.42
# SGD   0.41
# DKK   0.38
# NZD   0.35
# SEK   0.35
# CAD   0.34
# CHF   0.32
# NOK   0.31
# AUD   0.31
# MXN   0.29
# EUR   0.28
# Name: currency, dtype: float64

# %% [markdown]
# The USD dominates in frecuency and it's probabiliy is similar to the overall population probability.

# %%
#show the frequency of location city for those with at least 3000 instances
fig = plt.figure(figsize = (12, 6))
sns.countplot(x = 'city', hue = 'binary_state', 
              data = cleaned_data,
              order = cleaned_data.city.value_counts().head(9).index)
plt.legend(title ='')
plt.xlabel('Location City')
plt.title('Count of Location City (> 3000)')
plt.show()
# make this into a probability distribution like above
y = (cleaned_data['city'].loc[cleaned_data['city'].isin(cleaned_data.city.value_counts().head(9).index)].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['city'].loc[cleaned_data['city'].isin(cleaned_data.city.value_counts().head(9).index)].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order = y.index, palette = 'muted')
plt.xlabel('Location City')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by City')
plt.show()
print(y)
# Out:
# Brooklyn        0.72
# San Francisco   0.64
# Portland        0.62
# New York        0.61
# Seattle         0.60
# Chicago         0.54
# Los Angeles     0.54
# London          0.46
# Atlanta         0.32
# Name: city, dtype: float64

# %% [markdown]
# The major US cities for launch were more successful than average except for Atlanta which was well below average. This is perhaps a proxy for income or disposable income. London came in slightly above average, but was probably hurt by not being in the US. Brooklyn is the Kickstarter headquarters.

# %%
#create a Cali or NY column
cleaned_data['ca_ny'] = [i == 'CA' or i == 'NY' for i in cleaned_data.location_state]
print(cleaned_data.ca_ny.value_counts())
print(cleaned_data.ca_ny.loc[cleaned_data.binary_state == 1].value_counts()/cleaned_data.ca_ny.value_counts())
cleaned_data.drop(columns=['city', 'location_state'], inplace=True)
# Out:
# False    206512
# True      61167
# Name: ca_ny, dtype: int64
# False   nan
# True    nan
# Name: ca_ny, dtype: float64

# %%
fig = plt.figure(figsize = (12, 6))
chart = sns.countplot(x = 'category_name', hue = 'binary_state', data = cleaned_data, order=cleaned_data.category_name.value_counts().iloc[:10].index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(title ='')
plt.xlabel('Category Name')
plt.title("Count of Category Name (Top 10)")
plt.show()
#probability distribution
y = (cleaned_data['category_name'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['category_name'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order=cleaned_data.category_name.value_counts().iloc[:10].index, palette = 'muted')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.xlabel('Category Name')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Category Name')
plt.show()

# %% [markdown]
# There are very high variability between categories with Apps being extremely unsuccessful and shorts (clothing) being very successful.

# %%
fig = plt.figure(figsize = (12, 6))
chart = sns.countplot(x = 'category_slug', hue = 'binary_state', data = cleaned_data, order=cleaned_data.category_slug.value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(title ='')
plt.xlabel('Category Slug')
plt.title("Count of Category Slug")
plt.show()

#probability distribution
y = (cleaned_data['category_slug'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['category_slug'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order=cleaned_data.category_slug.value_counts().index, palette = 'muted')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.xlabel('Category Slug')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful Category Slug')
plt.show()

# %% [markdown]
# Category slug may be more informative than category name due to too much fragmentation of the data with the numerous category names.

# %%
#dropping category name due to high number of categories and high variability
cleaned_data.drop(columns='category_name', inplace = True)

# %%
fig = plt.figure(figsize = (12, 6))
chart = sns.countplot(x = 'location_type', hue = 'binary_state', data = cleaned_data, order=cleaned_data.location_type.value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(title ='')
plt.xlabel('Location Type')
plt.title("Count of Location Type")
plt.show()

#probability distribution
y = (cleaned_data['location_type'].loc[cleaned_data['binary_state'] == 'successful'].value_counts())/(cleaned_data['location_type'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order=y.index, palette = 'muted')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.xlabel('Location Type')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Location Type')
plt.show()

# %%
#too much concentration in town for the data to be useful?
print(cleaned_data.location_type.value_counts())
cleaned_data.drop(columns='location_type', inplace = True)
# Out:
# Town             248723
# County             9464
# Suburb             6276
# LocalAdmin         1341
# Miscellaneous       921
# Zip                 567
# Island              359
# Country              21
# Estate                7
# Name: location_type, dtype: int64

# %%
#convert binary state to boolean
d = {'successful': True, 'failed' : False}
cleaned_data['binary_state'] = cleaned_data['binary_state'].map(d)

# %%
#binning the data to look at probabilities by goal USD
cleaned_data['qcut_goal'] = pd.qcut(cleaned_data['goal_USD'], q=8, precision = 0)
#probability distribution
y = (cleaned_data['qcut_goal'].loc[cleaned_data['binary_state'] == True].value_counts())/(cleaned_data['qcut_goal'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order=y.index, palette = 'muted')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.xlabel('USD Goal Binned Data')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Goal')
plt.show()

print(y)
# Out:
# (999.0, 1963.0]          0.55
# (1963.0, 3000.0]         0.54
# (3000.0, 5000.0]         0.49
# (5000.0, 7000.0]         0.47
# (7000.0, 10000.0]        0.44
# (10000.0, 18187.0]       0.42
# (18187.0, 36945.0]       0.35
# (36945.0, 152350076.0]   0.19
# Name: qcut_goal, dtype: float64

# %% [markdown]
# As expected, probability declines with increasing USD goal amount.

# %%
cleaned_data['cut_static_rate'] = pd.cut(cleaned_data['static_usd_rate'], [0,0.755, 0.9999,1.0001, 1.3, 10])
print(cleaned_data.cut_static_rate.value_counts())
#probability distribution
y = (cleaned_data['cut_static_rate'].loc[cleaned_data['binary_state'] == True].value_counts())/(cleaned_data['cut_static_rate'].value_counts())
y = y.sort_values(ascending = False)
fig=plt.figure(figsize=(12,6))
ax = sns.barplot(x = y.index, y = y, order=y.index, palette = 'muted')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.xlabel('USD Exchange Rate')
plt.ylabel('Proporation of Successful')
plt.title('Proportion of Successful by Exchange Rate to USD')
plt.show()
# Out:
# (0.9999, 1.0001]    203039
# (1.0001, 1.3]        20855
# (1.3, 10.0]          19064
# (0.755, 0.9999]      12613
# (0.0, 0.755]         12108
# Name: cut_static_rate, dtype: int64

# %% [markdown]
# Items listed in USD had the highest probability of success. There were mixed results for other currency, but the most valueable currency column did the second best. There will likely be heavy correlation with location_country. However, it won't be perfect as exchange rates change and not all US projects were listed in USD. I will likely drop this column later this was more for experimentation purposes.

# %% [markdown]
# ## Correlations

# %%
# defining correlation matrix (taken from Kaggle starter code)
def plotCorrelationMatrix(df, graphWidth):
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(cleaned_data, 10)

# %% [markdown]
# There don't appear to be any surprising correlations. Backers count and prop goal should be removed due to correlation with USD pledged. Goal should be removed due to heavy correlation with goal USD. Year has no impact on the future of success. Qcut_goal and cut_static_rate were used for visualization purposes only and will be removed. We are trying to predict success or failure, so USD_pledged is not necessary. Blurb and name are not necessary any more. Deadline is no longer necessary. Currency doesn't seem necessary, but I will also remove static USD rate as it doesn't seem to be impactful, but may consider adding it back and manipulating it in the future.
#
# Launched at should be kept initially for slicing.

# %% [markdown]
# ## Modeling

# %%
#removing columns while keeping launched at for slicing purposes
#consider removing earlier years first
cleaned_data.drop(columns=['currency', 'static_usd_rate', 'backers_count', 'prop_goal', 'goal', 'year', 'qcut_goal', 'cut_static_rate', 'usd_pledged', 'blurb', 'name', 'deadline'], inplace = True)

# %%
#slicing data to used late data for test data

#sharp drop off in success starting in July 2014, so slicing before then
early_data = cleaned_data.loc[cleaned_data.launched_at < '2014-07-01']
print(len(early_data))

#data goes through mid-April 2019 but not may projects launched in April would also have an April deadline, so taking data from March
middle_data = cleaned_data.loc[(cleaned_data.launched_at >= '2014-07-01') & (cleaned_data.launched_at < '2018-03-01')]
print(len(middle_data))

#late data to capture the whole last year    
late_data = cleaned_data.loc[cleaned_data.launched_at >= '2018-03-01']
print(len(late_data))

#all other data
train_data = cleaned_data.loc[cleaned_data.launched_at < '2018-03-01']
print(len(train_data))

data_splits = [early_data, middle_data, late_data, train_data]
# Out:
# 81037
# 153804
# 32838
# 234841

# %%
#remove cleaned_data from memory
del cleaned_data

# %%
#getting data ready for modeling

for i in range(len(data_splits)):
        data_splits[i] = pd.get_dummies(data_splits[i], columns = ['category_slug', 'month', 'day_week']) #I did not drop first because using RF
print(data_splits[3].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234841 entries, 8624 to 2147476221
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   launched_at                 234841 non-null  datetime64[ns]
#  1   goal_USD                    234841 non-null  float64
#  2   blurb_length                234841 non-null  int64
#  3   binary_state                234841 non-null  bool
#  4   days_between                234841 non-null  int64
#  5   name_length                 234841 non-null  int64
#  6   help_first_blurb            234841 non-null  bool
#  7   lowercase_first             234841 non-null  bool
#  8   first_name_cap              234841 non-null  bool
#  9   exclam                      234841 non-null  bool
#  10  ca_ny                       234841 non-null  bool
#  11  category_slug_art           234841 non-null  uint8
#  12  category_slug_comics        234841 non-null  uint8
#  13  category_slug_crafts        234841 non-null  uint8
#  14  category_slug_dance         234841 non-null  uint8
#  15  category_slug_design        234841 non-null  uint8
#  16  category_slug_fashion       234841 non-null  uint8
#  17  category_slug_film & video  234841 non-null  uint8
#  18  category_slug_food          234841 non-null  uint8
#  19  category_slug_games         234841 non-null  uint8
#  20  category_slug_journalism    234841 non-null  uint8
#  21  category_slug_music         234841 non-null  uint8
#  22  category_slug_photography   234841 non-null  uint8
#  23  category_slug_publishing    234841 non-null  uint8
#  24  category_slug_technology    234841 non-null  uint8
#  25  category_slug_theater       234841 non-null  uint8
#  26  month_April                 234841 non-null  uint8
#  27  month_August                234841 non-null  uint8
#  28  month_December              234841 non-null  uint8
#  29  month_February              234841 non-null  uint8
#  30  month_January               234841 non-null  uint8
#  31  month_July                  234841 non-null  uint8
#  32  month_June                  234841 non-null  uint8
#  33  month_March                 234841 non-null  uint8
#  34  month_May                   234841 non-null  uint8
#  35  month_November              234841 non-null  uint8
#  36  month_October               234841 non-null  uint8
#  37  month_September             234841 non-null  uint8
#  38  day_week_Friday             234841 non-null  uint8
#  39  day_week_Monday             234841 non-null  uint8
#  40  day_week_Saturday           234841 non-null  uint8
#  41  day_week_Sunday             234841 non-null  uint8
#  42  day_week_Thursday           234841 non-null  uint8
#  43  day_week_Tuesday            234841 non-null  uint8
#  44  day_week_Wednesday          234841 non-null  uint8
# dtypes: bool(6), datetime64[ns](1), float64(1), int64(3), uint8(34)
# memory usage: 19.7 MB
# None

# %%
#splitting everything out again for the first model with all data against the most recent (test) data
test_labels = np.array(data_splits[2]['binary_state'])
test_features = data_splits[2].drop(['binary_state', 'launched_at'], axis=1)
train_labels = np.array(data_splits[3]['binary_state'])
train_features = data_splits[3].drop(['binary_state', 'launched_at'], axis = 1)
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)

#feature_list
feature_list = list(train_features.columns)
# Out:
# Training Features Shape: (234841, 43)
# Training Labels Shape: (234841,)
# Testing Features Shape: (32838, 43)
# Testing Labels Shape: (32838,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestClassifier
# Create the model with 100 trees
model = RandomForestClassifier(n_estimators=100,
                               random_state=112,
                               bootstrap = True,
                               max_features = 'sqrt')
# Fit on training data
model.fit(train_features, train_labels)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=112,
#                        verbose=0, warm_start=False)

# %%
# Actual class predictions
rf_predictions = model.predict(test_features)
# Probabilities for each class
rf_probs = model.predict_proba(test_features)[:, 1]

# %%
#change the float display for modeling
pd.options.display.float_format = "{:.4f}".format
from sklearn.metrics import roc_auc_score

# Calculate roc auc
roc_value = roc_auc_score(test_labels, rf_probs)
print("Accuracy on test data:     {:0.4f}".format(roc_value))
# Out:
# Accuracy on test data:     0.7064

# %%
fi = pd.DataFrame({'feature': feature_list,
                   'importance': model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# Display
fi.head(10)
# Out:
#                feature  importance
# 0             goal_USD      0.2209
# 1         blurb_length      0.1506
# 2         days_between      0.1229
# 3          name_length      0.1131
# 7               exclam      0.0187
# 8                ca_ny      0.0168
# 42  day_week_Wednesday      0.0154
# 37     day_week_Monday      0.0153
# 6       first_name_cap      0.0151
# 40   day_week_Thursday      0.0149
